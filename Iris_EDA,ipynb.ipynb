# %%
import pandas as pd

# %%
df = pd.read_csv("Iris.csv")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 df = pd.read_csv("Iris.csv")
#
# File C:\anacoda\Lib\site-packages\pandas\io\parsers\readers.py:948, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#     935 kwds_defaults = _refine_defaults_read(
#     936     dialect,
#     937     delimiter,
# ...

# %%
import os
os.getcwd()
# Out:
# 'C:\\Users\\Wasmia Tariq'

# %%
import pandas as pd

df = pd.read_csv(r"C:\Users\Wasmia Tariq\Downloads\Iris.csv")
df.head()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[4], line 3
#       1 import pandas as pd
# ----> 3 df = pd.read_csv(r"C:\Users\Wasmia Tariq\Downloads\Iris.csv")
#       4 df.head()
#
# File C:\anacoda\Lib\site-packages\pandas\io\parsers\readers.py:948, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
# ...

# %%
import os
os.listdir(r"C:\Users\Wasmia Tariq\Downloads")
# Out:
# ['11 lect.pptx',
#  '114(1) (Return of Income for a person deriving income only from salary and other sources eligible to file salary return)_2024 (5).pdf',
#  '123.ipynb',
#  '1430.doc',
#  '1502785629SJA_33_3_385-396.pdf',
#  '1605007236-biostatistics-daniel-10th1.pdf',
#  '1974 to 2018.xlsx',
#  '2-Attendance Spring 2024.xlsx',
#  '2022-2026_Fall_Award List-BS Botany_Reg & SS.xlsx',
#  '2025-10-15 11-13.pdf',
#  '2025-10-22 21-26.pdf',
#  '2025-10-22 21-26_compressed.pdf',
#  '2025-10-22 21-26_compressed_compressed.pdf',
#  '2025-10-22 21-26_compressed_compressed_compressed.pdf',
#  '2025-10-22 21-26_compressed_compressed_compressed_11zon.pdf',
#  '2025-10-22 22-10.pdf',
#  '3-14590182-4-2009-1-127001 (2).PDF',
#  '3840350198436.pdf',
#  '42Noor Sehar thesis.docx',
#  '4rd Sem 2023-28(1) PHARMACY.xls',
#  '4rd Sem 2023-28.xls',
#  '93UQ9D-TICKETS PIA KARWAN E TEHSEEN.pdf',
#  'ACCEPTANCE FORM SPRING 2024 (1).docx',
#  'ACCEPTANCE FORM SPRING 2024.docx',
# ...

# %%
import pandas as pd

df = pd.read_csv(r"C:\Users\Wasmia Tariq\Downloads\archive\Iris.csv")

# %%
df.head()
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             150 non-null    int64
#  1   SepalLengthCm  150 non-null    float64
#  2   SepalWidthCm   150 non-null    float64
#  3   PetalLengthCm  150 non-null    float64
#  4   PetalWidthCm   150 non-null    float64
#  5   Species        150 non-null    object
# dtypes: float64(4), int64(1), object(1)
# memory usage: 7.2+ KB

# %%
df.describe()
# Out:
#                Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# count  150.000000     150.000000    150.000000     150.000000    150.000000
# mean    75.500000       5.843333      3.054000       3.758667      1.198667
# std     43.445368       0.828066      0.433594       1.764420      0.763161
# min      1.000000       4.300000      2.000000       1.000000      0.100000
# 25%     38.250000       5.100000      2.800000       1.600000      0.300000
# 50%     75.500000       5.800000      3.000000       4.350000      1.300000
# 75%    112.750000       6.400000      3.300000       5.100000      1.800000
# max    150.000000       7.900000      4.400000       6.900000      2.500000

# %%
df.columns
# Out:
# Index(['Id', 'SepalLengthCm', 'SepalWidthCm', 'PetalLengthCm', 'PetalWidthCm',
#        'Species'],
#       dtype='object')

# %%
df.shape
# Out:
# (150, 6)

# %%
df.isnull().sum()
# Out:
# Id               0
# SepalLengthCm    0
# SepalWidthCm     0
# PetalLengthCm    0
# PetalWidthCm     0
# Species          0
# dtype: int64

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv(r"C:\Users\Wasmia Tariq\Downloads\archive\Iris.csv")

# %%
print(df.head())

print("\nShape:")
print(df.shape)

print("\nColumns:")
print(df.columns)

print("\nInformation:")
df.info()

print("\nSummary Statistics:")
print(df.describe())

print("\nMissing Values:")
print(df.isnull().sum())
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa
#
# Shape:
# (150, 6)
#
# Columns:
# Index(['Id', 'SepalLengthCm', 'SepalWidthCm', 'PetalLengthCm', 'PetalWidthCm',
#        'Species'],
#       dtype='object')
#
# Information:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             150 non-null    int64
#  1   SepalLengthCm  150 non-null    float64
#  2   SepalWidthCm   150 non-null    float64
# ...

# %%
df["Species"].value_counts()
# Out:
# Species
# Iris-setosa        50
# Iris-versicolor    50
# Iris-virginica     50
# Name: count, dtype: int64

# %%
plt.figure(figsize=(7,5))

plt.hist(df["SepalLengthCm"], bins=10)

plt.title("Distribution of Sepal Length")
plt.xlabel("Sepal Length (cm)")
plt.ylabel("Frequency")

plt.show()

# %%
plt.figure(figsize=(7,5))

plt.scatter(df["SepalLengthCm"], df["PetalLengthCm"])

plt.title("Sepal Length vs Petal Length")

plt.xlabel("Sepal Length")

plt.ylabel("Petal Length")

plt.show()

# %%
numeric_df = df.select_dtypes(include="number")

correlation = numeric_df.corr()

print(correlation)
# Out:
#                      Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  \
# Id             1.000000       0.716676     -0.397729       0.882747
# SepalLengthCm  0.716676       1.000000     -0.109369       0.871754
# SepalWidthCm  -0.397729      -0.109369      1.000000      -0.420516
# PetalLengthCm  0.882747       0.871754     -0.420516       1.000000
# PetalWidthCm   0.899759       0.817954     -0.356544       0.962757
#
#                PetalWidthCm
# Id                 0.899759
# SepalLengthCm      0.817954
# SepalWidthCm      -0.356544
# PetalLengthCm      0.962757
# PetalWidthCm       1.000000

# %%
plt.figure(figsize=(7,5))

plt.hist(df["SepalLengthCm"], bins=10)

plt.title("Distribution of Sepal Length")
plt.xlabel("Sepal Length (cm)")
plt.ylabel("Frequency")

plt.savefig("histogram.png", dpi=300, bbox_inches="tight")

plt.show()

# %%
import os
os.getcwd()
# Out:
# 'C:\\Users\\Wasmia Tariq'

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(7,5))
plt.hist(df["SepalLengthCm"], bins=10)

plt.title("Distribution of Sepal Length")
plt.xlabel("Sepal Length (cm)")
plt.ylabel("Frequency")

plt.savefig("histogram.png", dpi=300, bbox_inches="tight")

plt.show()

# %%
import os
os.getcwd()
# Out:
# 'C:\\Users\\Wasmia Tariq'

# %%
import os

os.listdir()
# Out:
# ['.anaconda',
#  '.conda',
#  '.condarc',
#  '.continuum',
#  '.ipynb_checkpoints',
#  '.ipython',
#  '.jupyter',
#  '.keras',
#  '.matplotlib',
#  '.spyder-py3',
#  '.virtual_documents',
#  '123.ipynb',
#  '3D Objects',
#  'A1.jpg',
#  'ADF_2ndDiff_Results.xlsx',
#  'ADF_Test_Results.xlsx',
#  'ADF_Test_Results_ARIMA.xlsx',
#  'AppData',
#  'Application Data',
#  'arima .ipynb',
#  'ARIMA_Forecast_Results.xlsx',
#  'ARIMA_Results_PP_All.xlsx',
#  'ARIMA_Results_PP_Stationary.xlsx',
#  'attendance.csv',
#  'attendance_form.html',
#  'brain tumor.ipynb',
#  'class attendence register.ipynb',
#  'comb...rf_param_combinations.csv',
#  'combination.rf_gridsearch_results.csv',
#  'Contacts',
#  'Cookies',
#  'crop_forecasting_results.xlsx',
#  'crop_forecasting_results_improved.xlsx',
#  'crop_forecasting_results_no_prophet.xlsx',
#  'CV for Maria Sarfraz.ipynb',
#  'data_project',
#  'Desktop',
#  'Documents',
#  'documnent',
#  'Downloads',
#  'Favorites',
#  'hira_project data.ipynb',
# ...

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(7,5))
plt.scatter(df["SepalLengthCm"], df["PetalLengthCm"])

plt.title("Sepal Length vs Petal Length")
plt.xlabel("Sepal Length")
plt.ylabel("Petal Length")

plt.savefig("scatter_plot.png", dpi=300, bbox_inches="tight")

plt.show()

# %%
import os
os.path.exists("scatter_plot.png")
# Out:
# True

# %%
import os
os.listdir()
# Out:
# ['.anaconda',
#  '.conda',
#  '.condarc',
#  '.continuum',
#  '.ipynb_checkpoints',
#  '.ipython',
#  '.jupyter',
#  '.keras',
#  '.matplotlib',
#  '.spyder-py3',
#  '.virtual_documents',
#  '123.ipynb',
#  '3D Objects',
#  'A1.jpg',
#  'ADF_2ndDiff_Results.xlsx',
#  'ADF_Test_Results.xlsx',
#  'ADF_Test_Results_ARIMA.xlsx',
#  'AppData',
#  'Application Data',
#  'arima .ipynb',
#  'ARIMA_Forecast_Results.xlsx',
#  'ARIMA_Results_PP_All.xlsx',
#  'ARIMA_Results_PP_Stationary.xlsx',
#  'attendance.csv',
#  'attendance_form.html',
#  'brain tumor.ipynb',
#  'class attendence register.ipynb',
#  'comb...rf_param_combinations.csv',
#  'combination.rf_gridsearch_results.csv',
#  'Contacts',
#  'Cookies',
#  'crop_forecasting_results.xlsx',
#  'crop_forecasting_results_improved.xlsx',
#  'crop_forecasting_results_no_prophet.xlsx',
#  'CV for Maria Sarfraz.ipynb',
#  'data_project',
#  'Desktop',
#  'Documents',
#  'documnent',
#  'Downloads',
#  'Favorites',
#  'hira_project data.ipynb',
# ...
